# %%
import math
import numbers

# %%
class Vector:
    """
    class to work with vectors without help of numpy
    vector1 = Vector(list) = Vector(tuple)

    """
    def __init__(self, vector):

        self.source = vector
        if isinstance(vector, Vector) is True:
            self.source = vector.source
            
        self.x = self[0]
        self.y = self[1]
        self.z = self[2]
            
    @property
    def magnitude(self):
        mag = sum([x**2 for x in self])**0.5
        return mag
    
    @property
    def direction(self):
        return self / self.magnitude
    
    def distance(self, vector):
        """
        Returns the distance between two points
        """

        dist = sum([(x - y)**2 for x, y in zip(self, vector)])**2

        return dist

    def angle(self, vector):
        """
        return the angle between two vectors
        """
        vector = Vector(vector)
        cos = self.dot(vector) / (self.magnitude * vector.magnitude)

        return math.acos(cos)


    def dot(self, vector):
        """
        returns the dot product of two vectors
        """
        if isinstance(vector, Vector) is False:
            vector = Vector(vector)
        result = sum([x*y for x, y in zip(self, vector)])

        return result

    def cross(self, vector):
        """
        returns the cross product of two vectors
        """

        a1, a2, a3 = self
        b1, b2, b3 = vector
        result = [a2*b3 - a3*b2,
                  a1*b3 - a3*b1,
                  a1*b2 - a2*b1]

        return Vector(result)
    
    def plot(self):
        from mpl_toolkits import mplot3d
        import matplotlib.pyplot as plt
        fig = plt.figure()
        ax = plt.axes(projection='3d')
        
        xline = [0, self[0]]
        yline = [0, self[1]]
        zline = [0, self[2]]
        ax.plot3D(xline, yline, zline, 'gray')
        plt.show()

    
    def __getitem__(self, item):
        """
        This does some magic
        """
        return self.source[item]

    def __repr__(self):
    
        return "Vector(%s)" % self.source    
    
    def __add__(self, other):
        """
        Define addition of vectors and forbid the addition with other objects
        """
        if not isinstance(other, (self.__class__, list, tuple)):
            raise TypeError(
                'Can only operate on {0}.'.format(self.__class__.__name__))
            
        else:
            return Vector([i + j for i, j in zip(self, other)])

    def __sub__(self, other):
        """
        Define subtraction of vectors and forbid it with other objects
        """
        if not isinstance(other, (self.__class__, list, tuple)):
            raise TypeError(
                'Can only operate on {0}.'.format(self.__class__.__name__))
            
        else:
            return Vector([i - j for i, j in zip(self, other)])

    def __mul__(self, other):
        """
        Define what can be multiplied and what not
        """
        if not isinstance(other, numbers.Number):
            raise TypeError
        else:
            return Vector([j*other for j in self])
        

    def __truediv__(self, other): # __truediv__???
        """
        Define what can be divided and what not
        """
        if not isinstance(other, numbers.Number):
            raise TypeError
        else:
            return Vector([j/other for j in self])
        
    def __lt__(self, other):
        if not isinstance(other, (self.__class__, list, tuple)):
            raise TypeError
        else:
            return self.magnitude < Vector(other).magnitudeNo evidence means no evidence statistically at this time. The sample size in the study is ridiculously small, it’s way too early to make this judgment in a UK context.


        
    def __eq__(self, other):
        if not isinstance(other, (self.__class__, list, tuple)):
            raise TypeError
        else:
            v = Vector(other)
            return self[0] == v[0] and self[1] == v[1] and self[2] == v[2]
        

    def __repr__(self):
        s = "Vector([%s, %s, %s])" % (self[0], self[1], self[2])
        return s

# %%
v1 = Vector([1,2,3])
v2 = Vector([10, 20, 30]) /10
v3 = v1 + [20, 30, 40]
a=2
v1 > v2
# Out:
# False

# %%
v1.plot()

# %%
import glob
import mimetypes
import magic
import os

# %%
files = glob.glob("*")

# %%
f = open("text", "w")

for f in files:
    t = magic.from_file(f)
    f.
# Out:
#   File "/tmp/ipykernel_24505/1658100205.py", line 5
#     f.
#       ^
# SyntaxError: invalid syntax

# %%
for k, v in os.environ.items():
    print(f'{k}-{v}')
# Out:
# CONDA_SHLVL:1
# LS_COLORS:rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=30;41:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.Z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.wim=01;31:*.swm=01;31:*.dwm=01;31:*.esd=01;31:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra=00;36:*.wav=00;36:*.oga=00;36:*.opus=00;36:*.spx=00;36:*.xspf=00;36:
# CONDA_EXE:/home/mverdugo/anaconda/bin/conda
# LC_MEASUREMENT:de_AT.UTF-8
# LESSCLOSE:/usr/bin/lesspipe %s %s
# LC_PAPER:de_AT.UTF-8
# LC_MONETARY:de_AT.UTF-8
# LANG:en_US.UTF-8
# GDM_LANG:en_US
# DISPLAY::0
# OLDPWD:/home/mverdugo/Desktop/Informatik/WS2021/Exercise_07
# GTK_OVERLAY_SCROLLING:1
# COLORTERM:truecolor
# PYSYN_CDBS:/home/mverdugo/anaconda/CDBS
# CONDA_PREFIX:/home/mverdugo/anaconda
# XDG_VTNR:7
# SSH_AUTH_SOCK:/run/user/1000/keyring/ssh
# MANDATORY_PATH:/usr/share/gconf/cinnamon.mandatory.path
# _CE_M:
# LC_NAME:de_AT.UTF-8
# XDG_SESSION_ID:c2
# XDG_GREETER_DATA_DIR:/var/lib/lightdm-data/mverdugo
# USER:mverdugo
# DESKTOP_SESSION:cinnamon
# GNOME_TERMINAL_SCREEN:/org/gnome/Terminal/screen/ae1eec10_462b_4d6c_9ad0_5fb8f0cdc09a
# DEFAULTS_PATH:/usr/share/gconf/cinnamon.default.path
# QT_QPA_PLATFORMTHEME:qt5ct
# PWD:/home/mverdugo/Desktop/Informatik/WS2021/Exercise_07/solutions
# HOME:/home/mverdugo
# CONDA_PYTHON_EXE:/home/mverdugo/anaconda/bin/python
# SSH_AGENT_PID:1419
# QT_ACCESSIBILITY:1
# XDG_SESSION_TYPE:x11
# XDG_DATA_DIRS:/usr/share/cinnamon:/usr/share/gnome:/home/mverdugo/.local/share/flatpak/exports/share:/var/lib/flatpak/exports/share:/usr/local/share:/usr/share:/var/lib/snapd/desktop
# _CE_CONDA:
# XDG_SESSION_DESKTOP:cinnamon
# LC_ADDRESS:de_AT.UTF-8
# GJS_DEBUG_OUTPUT:stderr
# LC_NUMERIC:de_AT.UTF-8
# CONDA_PROMPT_MODIFIER:(base)
# GTK_MODULES:gail:atk-bridge
# TERM:xterm-color
# SHELL:/bin/bash
# VTE_VERSION:5202
# XDG_SEAT_PATH:/org/freedesktop/DisplayManager/Seat0
# XDG_CURRENT_DESKTOP:X-Cinnamon
# GPG_AGENT_INFO:/run/user/1000/gnupg/S.gpg-agent:0:1
# GNOME_TERMINAL_SERVICE::1.380
# XDG_SEAT:seat0
# SHLVL:1
# LANGUAGE:en_US
# LC_TELEPHONE:de_AT.UTF-8
# GDMSESSION:cinnamon
# GNOME_DESKTOP_SESSION_ID:this-is-deprecated
# LOGNAME:mverdugo
# DBUS_SESSION_BUS_ADDRESS:unix:path=/run/user/1000/bus
# XDG_RUNTIME_DIR:/run/user/1000
# XAUTHORITY:/home/mverdugo/.Xauthority
# XDG_SESSION_PATH:/org/freedesktop/DisplayManager/Session0
# XDG_CONFIG_DIRS:/etc/xdg/xdg-cinnamon:/etc/xdg
# PATH:/home/mverdugo/anaconda/bin:/home/mverdugo/anaconda/condabin:/home/mverdugo/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin:/home/mverdugo:/home/mverdugo/bin:/home/mverdugo/Astromatic/bin:/home/mverdugo/esorex/bin/
# LC_IDENTIFICATION:de_AT.UTF-8
# PS1:\[\e\]\u@\h:\[\033\]\w>\[\033\]
# CINNAMON_VERSION:4.4.8
# bc03:/home/mverdugo/DATA/BC03_models/bc03/src
# CONDA_DEFAULT_ENV:base
# GJS_DEBUG_TOPICS:JS ERROR;JS LOG
# SESSION_MANAGER:local/peumo:@/tmp/.ICE-unix/1342,unix/peumo:/tmp/.ICE-unix/1342
# LESSOPEN:| /usr/bin/lesspipe %s
# _:/home/mverdugo/anaconda/bin/jupyter
# JPY_PARENT_PID:21591
# CLICOLOR:1
# PAGER:cat
# GIT_PAGER:cat
# MPLBACKEND:module://matplotlib_inline.backend_inline
