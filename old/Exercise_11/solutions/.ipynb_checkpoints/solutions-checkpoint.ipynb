# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import norm
from astropy.io import fits
import numpy as np

# %% [markdown]
# # Question 2
#
# The `FITS` file `MACSJ0416_HAWKI.fits` contains a near infrared (_Ks_-band) image of the center
#    of the cluster of galaxies `MACS J0416.1-2403` at $z=0.4$. It was taken with the HAWK-I instrument at
#    the VLT as part of the ESO contribution to the [FrontierFields program](http://gbrammer.github.io/HAWKI-FF/)).
#
#    - Using the `astropy` library, load that file in python and show us the most important parameters,
#      like image size and headers.
#
#    -  Display the previous image with `matplotlib` in a way that the objects can be distinguished by
#      eye (by adjusting the contrast). Find the pixel with the maximum value and draw a circle around it.
#      Finally save the image as a PDF file.

# %%
hdu = fits.open("../MACSJ0416_HAWKI.fits")
header = hdu[0].header
data = hdu[0].data

print(hdu.info())
print()
print(repr(header))
# Out:
# Filename: ../MACSJ0416_HAWKI.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     112   (1200, 1200)   float32
# None
#
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1200
# NAXIS2  =                 1200
# EQUINOX =              2000.0  / [yr] Equinox of equatorial coordinates
# RADECSYS= 'FK5     '           / Astrometric system
# CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
# CUNIT1  = 'deg     '           / Units of coordinate increment and value
# CRVAL1  =      64.08926666667  / [deg] Coordinate value at reference point
# CRPIX1  =              -1199.5 / Pixel coordinate of reference point
# CD1_1   =   -2.77777781917E-05 / Linear projection matrix
# CD1_2   =                  0.0 / Linear projection matrix
# CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
# CUNIT2  = 'deg     '           / Units of coordinate increment and value
# CRVAL2  =     -24.09461111111  / [deg] Coordinate value at reference point
# CRPIX2  =               -224.5 / Pixel coordinate of reference point
# CD2_1   =                  0.0 / Linear projection matrix
# CD2_2   =    2.77777781917E-05 / Linear projection matrix
# DATE    = '2016-05-02T13:25:58.268' / Creation date of ORIGFILE
# COMMENT
# COMMENT Phase 3 keywords
# COMMENT
# ORIGIN  = 'ESO-PARANAL'        / European Southern Observatory
# TELESCOP= 'ESO-VLT-U4'         / ESO telescope designation
# INSTRUME= 'HAWKI   '           / Instrument name
# DIT     =                  8.0 / Detector Integration Time (s)
# NDIT    =                    7 / Number of sub-integrations
# FILTER  = 'Ks      '           / Filter name
# OBJECT  = 'M0416   '           / Target designation
# RA      =       64.08926666667 / Image centre (FK5)
# DEC     =      -24.09461111111 / Image centre (FK5)
# EXPTIME =              74368.0 / Integration time per pixel, 0.8*TEXPTIME (s)
# TEXPTIME=              92960.0 / Total integration time of all exposures (s)
# MJD-OBS =       56591.1759894  / [d] MJD at start of observation
# MJD-END =        56712.065145  / [d] MJD at end of observation
# PROG_ID = 'MULTI   '           / ESO programme identification
# PROGID1 = '092.A-0472(A)'      / ESO programme identification
# PROGID2 = '092.A-0472(B)'      / ESO programme identification
# OBID1   =              1012500 / Observation block ID
# OBID2   =              1012504 / Observation block ID
# OBID3   =              1012506 / Observation block ID
# OBID4   =              1012508 / Observation block ID
# OBID5   =              1012510 / Observation block ID
# OBID6   =              1012512 / Observation block ID
# OBID7   =              1012514 / Observation block ID
# OBID8   =              1012516 / Observation block ID
# OBID9   =              1012518 / Observation block ID
# OBID10  =              1012520 / Observation block ID
# OBID11  =              1012522 / Observation block ID
# OBID12  =              1012524 / Observation block ID
# OBID13  =              1012526 / Observation block ID
# OBID14  =              1012528 / Observation block ID
# OBID15  =              1012530 / Observation block ID
# OBID16  =              1012532 / Observation block ID
# OBID17  =              1012534 / Observation block ID
# OBID18  =              1012536 / Observation block ID
# OBID19  =              1012538 / Observation block ID
# OBID20  =              1012542 / Observation block ID
# OBID21  =              1012544 / Observation block ID
# OBID22  =              1012546 / Observation block ID
# OBID23  =              1012548 / Observation block ID
# OBID24  =              1012550 / Observation block ID
# OBID25  =              1012552 / Observation block ID
# OBID26  =              1012554 / Observation block ID
# OBID27  =              1012556 / Observation block ID
# OBID28  =              1012558 / Observation block ID
# OBID29  =              1012560 / Observation block ID
# OBID30  =              1012562 / Observation block ID
# OBID31  =              1012564 / Observation block ID
# OBID32  =              1012566 / Observation block ID
# OBID33  =              1012582 / Observation block ID
# OBID34  =              1020084 / Observation block ID
# M_EPOCH =                    T / TRUE if resulting from multiple epochs
# NCOMBINE=                 1660 / # of combined raw science data files
# OBSTECH = 'IMAGE,JITTER'       / Technique for observation
# PRODCATG= 'SCIENCE.IMAGE'      / Data product category
# FLUXCAL = 'ABSOLUTE'           / Certifies the validity of PHOTZP
# BUNIT   = 'adu     '           / Physical unit of array values
# PHOTZP  =                 26.0 / Photometric zeropoint MAG=-2.5*log(data)+PHOTZP
# PHOTZPER=                 0.05 / Uncertainty of the photometric zeropoint
# PHOTSYS = 'AB      '           / Photometric system VEGA or AB
# PIVOT   =              21524.0 / Filter pivot wavelength
# ABVEGA  =                1.826 / AB-Vega conversion (mag)
# ABMAGLIM=                 26.0 / 5-sigma limiting AB magnitude for point sources
# ABMAGSAT=                 14.0 / Saturation limit for point sources (AB mag)
# PSF_FWHM=                 0.36 / FWHM for point sources (arcsec)
# ELLIPTIC=                0.034 / Average ellipticity of point sources
# PROCSOFT= 'HawkiDrizzle1.0'    / Data reduction software/system
# SOFTAUTH= 'Gabriel Brammer (brammer@stsci.edu)' / Software maintainer
# AUTHOR  = 'Brammer '           / Who ran the software
# REFERENC= '        '           / Bibliographic reference
# ASSON1  = 'KIFF_M0416_Ks_v1.0_wht.fits' / Name of the associated file
# PROVXTN =                    T / TRUE if proc. provenance recorded in FITS extn.
# CHECKSUM= 'TIFAWFD7TFDATFD5'   / HDU checksum updated 2020-01-16T13:47:18
# DATASUM = '2049836015'         / data unit checksum updated 2020-01-16T13:47:18
# ORIGFILE= 'KIFF_M0416_Ks_v1.0_sci.fits' / Original File Name
# ARCFILE = 'ADP.2016-06-06T12:19:44.049.fits' / Archive File Name
# P3ORIG  = 'EDP     '           / ESO external data product
# WCSAXES =                    2 / Number of coordinate axes
# PC1_1   =   -2.77777781917E-05 / Coordinate transformation matrix element
# PC2_2   =    2.77777781917E-05 / Coordinate transformation matrix element
# CDELT1  =                  1.0 / [deg] Coordinate increment at reference point
# CDELT2  =                  1.0 / [deg] Coordinate increment at reference point
# LONPOLE =                180.0 / [deg] Native longitude of celestial pole
# LATPOLE =      -24.09461111111 / [deg] Native latitude of celestial pole
# DATE-OBS= '2013-10-26T04:13:25.484' / ISO-8601 time of observation
# DATE-END= '2014-02-24T01:33:48.528' / ISO-8601 time at end of observation
# RADESYS = 'FK5'                / Equatorial coordinate system
# HISTORY Image was compressed by CFITSIO using scaled integer quantization:
# HISTORY   q = 4.000000 / quantized level scaling parameter
# HISTORY 'SUBTRACTIVE_DITHER_1' / Pixel Quantization Algorithm

# %%
fig = plt.figure(figsize=(12,12))

vmin = np.min(data)
vmax = np.median(data) + 3*np.std(data)
plt.imshow(data, origin="lower", vmin=vmin, vmax=vmax, cmap="magma")


(X, Y) = np.where(data == np.max(data))

plt.plot(Y[0], X[0], "o", ms=14, mfc="None", mec="r", mew=2)

plt.xlabel("X [pix]", fontsize=14)
plt.ylabel("Y [pix]", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.savefig("MACSJ0416_HAWKI.pdf")

# %% [markdown]
# # Question 3
#
# Do some statistics (mean, median and standard deviation) of the previous image using `numpy` statistical functions.
#    Create an histogram of the pixel values and plot it with `matplotlib`.
#
#    Now, using ``curvefit`` from ``scipy.optimize`` fit a Gaussian to the histogram values and determine
#    the center (mean) and the sigma (standard deviation) from the fit. Discuss the differences with values
#    derived by `numpy`.

# %%
print("mean: ", np.mean(data))
print("median: ", np.median(data))
print("standard deviation: ", np.std(data))
print("min: ", np.min(data))
print("max: ", np.max(data))

low_cut = np.min(data)
high_cut = np.mean(data) + 5*np.std(data)

data_cut =  data[(data>low_cut) & (data<high_cut) ]
values, edges, patches = plt.hist(data_cut.flatten(), bins=500)
centers = (edges[0:-1] + edges[1:]) / 2

plt.xlim(-0.5, 1.5)
# Out:
# mean:  0.06401208
# median:  0.006286473
# standard deviation:  0.67112803
# min:  -0.1543041
# max:  162.68599
# (-0.5, 1.5)

# %%
from scipy.optimize import curve_fit

def gaussian(x, mean, sigma, amplitude):
    return amplitude * np.exp(-(x - mean)**2 / (2 * sigma**2.))

results, cov_matrix = curve_fit(gaussian, centers, values, sigma=np.sqrt(values))

print("mean: ", results[0])
print("std: ", results[1])
print("amplitude: ", results[2])
# Out:
# mean:  0.003604400415099331
# std:  0.024655971266498565
# amplitude:  146065.66786952788

# %%
values, edges, patches = plt.hist(data_cut.flatten(), bins=500)
x = np.arange(-1, 2, 0.001)
plt.plot(x, gaussian(x, results[0], results[1], results[2]), color="k")
plt.xlim(-0.25, 0.75)
# Out:
# (-0.25, 0.75)

# %% [markdown]
# # Question 4
#
# Consider the data table `rotcurve.txt` provided with this exercise. It contains data for a rotation curve
#    for a galaxy with columns `r` for radius, `vel` for velocity and the error in `vel`. Please read the file
#    (with `astropy`) and plot that information (including the errors) with `matplotlib`.
#
#    What is the maximum rotation velocity of this galaxy? Try to determine it by fitting the following
#    function to the data (but other ideas are also welcome)
#
#    $V(r) = \frac{2}{\pi} V_{max} \arctan(r/r_d)$,
#
#    where $r_d$ is the disk scale length, $\sim 5$ in this case, but can also be left as a free parameter.

# %%
from astropy.table import Table

tbl = Table.read("../rotcurve.txt", format="ascii")

r = tbl["r"]
vel = tbl["vel"]
e_vel = tbl["e_vel"]

plt.errorbar(r, vel, e_vel)
plt.xlabel("radius")
plt.ylabel("vel")
# Out:
# Text(0, 0.5, 'vel')

# %%
def vel_curve(r, vmax, r_d):
    return (2/np.pi) * vmax * np.arctan(r / r_d)

results, cov_matrix = curve_fit(vel_curve, r, vel, p0=[100, 5], sigma=e_vel)

plt.errorbar(r, vel, e_vel)
plt.plot(r, vel_curve(r, results[0], results[1]))

print("vmax=", results[0])
print("r_d", results[1])
plt.xlabel("radius")
plt.ylabel("vel")
# Out:
# vmax= 123.51962479823341
# r_d 0.9699383895661956
# Text(0, 0.5, 'vel')

# %% [markdown]
# # Question 5
#
# The file `SDSS_spec_galaxy.csv` contains the spectrum of a star forming galaxy observed as
#    part of the Sloan Digital Sky Survey. Load the spectra with ``astropy`` and make a plot with ``matplotlib``.
#
#    Knowing that the H$\alpha$ line at $\lambda=6562.8$ `Angstrom` (restframe) is the most intense line in this spectrum,
#    determine the redshift of this galaxy.
#
#    Overplot now the redshift corrected spectrum.

# %%
tbl = Table.read("../SDSS_spec_galaxy.csv")

wave = tbl["Wavelength"]
flux = tbl["Flux"]
plt.plot(wave, flux)
plt.xlabel("Wavelength [A]")
plt.ylabel("Flux")
# Out:
# Text(0, 0.5, 'Flux')

# %%
rest_wave = 6562.8

obs_wave = wave[flux==np.max(flux)]

z = (obs_wave - rest_wave) / rest_wave 

print("redshift is: ", z[0])
# Out:
# redshift is:  0.04594989943316869

# %%
plt.plot(wave, flux, label="observed spectrum")
plt.plot(wave/(1+z[0]), flux, label="corrected spectrum")
plt.xlabel("Wavelength [A]")
plt.ylabel("Flux")
plt.legend()
